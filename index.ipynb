# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('./src/Cancer_Data.csv',usecols=range(0, 32))
dataset.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# lets explore ours data

# %%
dataset.shape
dataset.index
dataset.columns
dataset.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# is there nan value?
dataset.isnull().values.any()
# Out:
# False

# %%
# really?
dataset.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
X.corr()
# Out:
#                          radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean                 1.000000      0.323782        0.997855   0.987357
# texture_mean                0.323782      1.000000        0.329533   0.321086
# perimeter_mean              0.997855      0.329533        1.000000   0.986507
# area_mean                   0.987357      0.321086        0.986507   1.000000
# smoothness_mean             0.170581     -0.023389        0.207278   0.177028
# compactness_mean            0.506124      0.236702        0.556936   0.498502
# concavity_mean              0.676764      0.302418        0.716136   0.685983
# concave points_mean         0.822529      0.293464        0.850977   0.823269
# symmetry_mean               0.147741      0.071401        0.183027   0.151293
# fractal_dimension_mean     -0.311631     -0.076437       -0.261477  -0.283110
# radius_se                   0.679090      0.275869        0.691765   0.732562
# ...

# %%
ax = sns.heatmap(X.corr(),cmap='coolwarm',annot=False,square=True)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
)
# Out:
# [Text(0.5, 0, 'radius_mean'),
#  Text(2.5, 0, 'perimeter_mean'),
#  Text(4.5, 0, 'smoothness_mean'),
#  Text(6.5, 0, 'concavity_mean'),
#  Text(8.5, 0, 'symmetry_mean'),
#  Text(10.5, 0, 'radius_se'),
#  Text(12.5, 0, 'perimeter_se'),
#  Text(14.5, 0, 'smoothness_se'),
#  Text(16.5, 0, 'concavity_se'),
#  Text(18.5, 0, 'symmetry_se'),
#  Text(20.5, 0, 'radius_worst'),
#  Text(22.5, 0, 'perimeter_worst'),
#  Text(24.5, 0, 'smoothness_worst'),
#  Text(26.5, 0, 'concavity_worst'),
#  Text(28.5, 0, 'symmetry_worst')]

# %%
corr = X.corr()
corr_5 = corr[corr > 0.8]
corr_matrix_high = corr_5.dropna(how='all').dropna(axis=1, how='all')

# Create a heatmap of the high correlation coefficients
sns.heatmap(corr_matrix_high, cmap='coolwarm')

# Display the plot
plt.show()

# %% [markdown]
# ### <u>Define</u> the label and train set

# %%
X = dataset.iloc[:, 2:32]
y = dataset.loc[:, 'diagnosis']
print(f"Shape of X: {X.shape}")
print(f"Shape of y: {y.shape}")
# Out:
# Shape of X: (569, 30)
# Shape of y: (569,)

# %%
y
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((398, 30), (171, 30), (398,), (171,))

# %%
X_train.iloc[:, 0:9]
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 478       11.490         14.59           73.99      404.9          0.10460
# 303       10.490         18.61           66.86      334.3          0.10680
# 155       12.250         17.94           78.27      460.3          0.08654
# 186       18.310         18.58          118.60     1041.0          0.08588
# 101        6.981         13.43           43.79      143.5          0.11700
# ..           ...           ...             ...        ...              ...
# 277       18.810         19.98          120.90     1102.0          0.08923
# 9         12.460         24.04           83.97      475.9          0.11860
# 359        9.436         18.32           59.82      278.6          0.10090
# 192        9.720         18.22           60.73      288.1          0.06950
# 559       11.510         23.93           74.52      403.5          0.09261
#
# ...

# %%
X_train.iloc[:, 10:20]
# Out:
#      radius_se  texture_se  perimeter_se  area_se  smoothness_se  \
# 478     0.2034      1.1660         1.567   14.340       0.004957
# 303     0.1485      1.5630         1.035   10.080       0.008875
# 155     0.2200      0.9823         1.484   16.510       0.005518
# 186     0.2577      0.4757         1.817   28.920       0.002866
# 101     0.2241      1.5080         1.553    9.833       0.010190
# ..         ...         ...           ...      ...            ...
# 277     0.3283      0.8280         2.363   36.740       0.007571
# 9       0.2976      1.5990         2.039   23.940       0.007149
# 359     0.5079      1.2470         3.267   30.480       0.006836
# 192     0.3539      4.8850         2.230   21.690       0.001713
# 559     0.2388      2.9040         1.936   16.970       0.008200
#
#      compactness_se  concavity_se  concave points_se  symmetry_se  \
# 478        0.021140       0.04156           0.008038      0.01843
# ...

# %%
X_train.iloc[:, 21:]
# Out:
#      texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 478          21.90            82.04       467.6           0.13520
# 303          24.54            70.76       375.4           0.14130
# 155          25.22            86.60       564.2           0.12170
# 186          26.36           139.20      1410.0           0.12340
# 101          19.54            50.41       185.2           0.15840
# ..             ...              ...         ...               ...
# 277          24.30           129.00      1236.0           0.12430
# 9            40.68            97.65       711.4           0.18530
# 359          25.02            75.79       439.6           0.13330
# 192          20.83            62.25       303.8           0.07117
# 559          37.16            82.28       474.2           0.12980
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 478            0.20100          0.25960               0.07431          0.2941
# ...

# %%
X_train.iloc[:, 27:]
# Out:
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 478               0.07431          0.2941                  0.09180
# 303               0.06528          0.2213                  0.07842
# 155               0.08211          0.3113                  0.08132
# 186               0.15710          0.3206                  0.06938
# 101               0.00000          0.2932                  0.09382
# ..                    ...             ...                      ...
# 277               0.12940          0.2567                  0.05737
# 9                 0.22100          0.4366                  0.20750
# 359               0.05052          0.2454                  0.08136
# 192               0.00000          0.1909                  0.06559
# 559               0.09653          0.2112                  0.08732
#
# [398 rows x 3 columns]

# %% [markdown]
# Simple visualization

# %%
y.hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# Modelling

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression, TweedieRegressor
